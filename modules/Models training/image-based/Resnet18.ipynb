# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
import torchvision.transforms as transforms
import torchvision.models as models
from PIL import Image
import os
import pandas as pd

class UserPhotoDataset(Dataset):
    def __init__(self, csv_file, root_dir, transform=None, max_photos=40):
        self.user_data = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transform = transform
        self.max_photos = max_photos

    def __len__(self):
        return len(self.user_data)

    def __getitem__(self, idx):
        user_row = self.user_data.iloc[idx]
        user = user_row['username']
        labels = user_row[['O', 'C', 'E', 'A', 'N']].values.astype('float32')
        user_dir = os.path.join(self.root_dir, user)

        if not os.path.exists(user_dir):
            print(f"Warning: User directory {user_dir} not found. Skipping this user.")
            return None

        photos = [os.path.join(user_dir, photo) for photo in os.listdir(user_dir)]

        # Truncate or pad photos to max_photos
        if len(photos) > self.max_photos:
            photos = photos[:self.max_photos]
        else:
            photos += [photos[0]] * (self.max_photos - len(photos))  # Repeat the first photo

        images = []
        for photo in photos:
            image = Image.open(photo)
            if self.transform:
                image = self.transform(image)
            images.append(image)

        images = torch.stack(images, dim=0)
        labels = torch.tensor(labels)
        return images, labels

    def __iter__(self):
        for idx in range(len(self)):
            item = self.__getitem__(idx)
            if item is not None:
                yield item

# %%
import torchvision.models as models
from torchvision.models import ResNet18_Weights

class UserClassifier(nn.Module):
    def __init__(self, num_labels):
        super(UserClassifier, self).__init__()
        self.feature_extractor = models.resnet18(weights=ResNet18_Weights.IMAGENET1K_V1)
        self.feature_extractor.fc = nn.Identity()  # Remove the final fully connected layer
        self.fc = nn.Linear(512, num_labels)  # Assuming ResNet18 and 512 features output

    def forward(self, x):
        # x is of shape (batch_size, num_photos, channels, height, width)
        batch_size, num_photos, channels, height, width = x.shape
        x = x.view(batch_size * num_photos, channels, height, width)
        features = self.feature_extractor(x)
        features = features.view(batch_size, num_photos, -1)
        aggregated_features = torch.mean(features, dim=1)
        out = self.fc(aggregated_features)
        return out

# %%
transform = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225]),
])

dataset = UserPhotoDataset(csv_file='/content/drive/MyDrive/PFA-Dataset/datas/filtered_final_data.csv',
                           root_dir='/content/drive/MyDrive/PFA-Dataset/Images', transform=transform)
dataloader = DataLoader(dataset, batch_size=4, shuffle=True, num_workers=2)


model = UserClassifier(num_labels=5)  # 5 binary labels
criterion = nn.BCEWithLogitsLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

num_epochs = 1

for epoch in range(num_epochs):
    model.train()
    running_loss = 0.0
    for i, (images, labels) in enumerate(dataloader):
        print(f"Batch {i+1}/{len(dataloader)}")
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {running_loss/len(dataloader)}')

# %%
torch.save(model.state_dict(), '/content/drive/Shareddrives/PFA_Dataset/models/cnnUser.pth')

# %%
model = UserClassifier(num_labels=5)  # Ensure that the architecture matches
model.load_state_dict(torch.load('/content/drive/MyDrive/PFA-Dataset/models/cnnUser.pth'))
model.eval()  # Set the model to evaluation mode
# Out:
# UserClassifier(
#   (feature_extractor): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Identity()
#   )
#   (fc): Linear(in_features=512, out_features=5, bias=True)
# )

# %% [markdown]
# ### Evaluating the model

# %%
dataset = UserPhotoDataset(
    csv_file='/content/drive/MyDrive/PFA-Dataset/datas/filtered_final_data.csv',
    root_dir='/content/drive/MyDrive/PFA-Dataset/Images',
    transform=transform
)

# Filter out None values in the DataLoader
dataloader = DataLoader(
    [item for item in dataset if item is not None],
    batch_size=4, shuffle=True, num_workers=2
)
# Out:
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/emilyhenrywrites not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/humminglion not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/henrygolding not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/maya_henry not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/henryrowleyy not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/_sarahmhen not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/sophie_aris not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/sophiejaynemiller not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/sophiemoulds not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/sophieferiani not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/sophiet not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/sophiestanbury not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/soturg not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/thatgirlsophy not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/sophie__church not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/sophiechapman87 not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/emily not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/emilydidonato not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/emilycanham not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/emilyanngemma not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/emilypayampss not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/emzchampion not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/emilyvartanian not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/hellomissjordan not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/emi.billings not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/emilyvelkovski not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/emilyrosdahl not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/_emilysworld not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/emilyijackson not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/arnelbee not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/arnelbee not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/sophiesuchan not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/sophiewyburd not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/emswells not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/thestemdiaries not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/jackblack not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/desiperkins not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/cmcoving not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/aliciakeys not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/kimikoglenn not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/alexanderludwig not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/harrymaguire93 not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/jamesolivercoaching not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/blondish not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/janayathefuture not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/emilywelchstyle not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/hummusbirrd not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/donte.colley not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/iambridgetkelly not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/giorgia.andriani22 not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/alexandrapereira not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/juliarestoinroitfeld not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/chalmeta not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/kellypiquet not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/chandacarroll not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/mirthamichelle not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/unjadedjade not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/leilalevchenko not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/_beatrips not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/emmaalexwatson1_ not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/amelie.kaced not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/spam.with.cas not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/ms_siska_wijaya not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/hiker_therapy not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/andrea.gomezpaez16 not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/strawberry_nymphat not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/sallyprosservoice not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/realtordlucas not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/penandpapergirl_wa not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/itskathryngrace not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/annmarielord_ not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/artist_lana_arkhi not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/kirstycarden not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/annavarga_yoga not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/tahliaswartz_naturopath not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/krishcamille.co not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/sammi_johnson_ not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/shanpowell.doula not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/rosielockhart not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/thewanderingwolfsta not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/stripesnchanel not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/tanyaburr not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/thisisbrooklynn not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/philippplein not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/missashaphilip not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/philip.sbrt not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/monicaroams not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/ryanphillippe not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/izabel.philippa not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/teganphillipa not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/philippklein not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/fernchisholm not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/schofe not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/philippabloom not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/phillipqvu not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/philipdeml not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/audreyrivet not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/audreyafs not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/audreyloques not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/audrey.leighton not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/audreyroloff not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/audreydiler not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/fourfeetnine not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/audboos not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/foodsofaudrey not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/thechrissyhazel not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/hazel_brady not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/thehazelhayes not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/hazelwoodx not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/freja_evelyn not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/evelynchengx not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/homewithevelyn not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/alessyafarrugiaa not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/amandaasad not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/arianagrande not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/ashleyseamour not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/averyywoods not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/beyonce not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/billieeilish not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/bukayosaka87 not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/centralcee not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/declanrice not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/elainamich not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/erling.haaland not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/evange not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/henbu_ not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/jackfalahee not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/jackgrealish not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/jamesarthur23 not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/jlo not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/joe_sugg not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/justinbieber not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/laurenconrad not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/lifewithdrsabra not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/mrbeast not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/nikiivictoria not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/rihannaofficiall not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/sincerelyjules not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/taylorswift not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/teddysphotos not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/theweeknd not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/zachking not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/erinmayhenry not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/henrymoodie not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/maryem.hz not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/ivy_cottage_country_living_ not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/ella_victoriaa not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/alexander.ayling not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/emilyalexaander not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/edwinatopsalexander not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/_amberalexander not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/jes_alex not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/alexcosta not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/alexzverev123 not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/harryclarke6 not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/aikines not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/jamieoliver not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/olivermoy not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/olivermuhl not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/makingathletes not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/juliene.sinclair not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/thomas.maddens not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/thomreads not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/thohay not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/thomasdelauer not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/thomasmandra not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/thomas_rossier not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/bashy not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/iwanrunner not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/thomasyeum not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/briannajoye_fitness not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/haley_pavone not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/katarinavidd not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/best.chefme not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/drchatterjee not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/kateehutchins not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/kellyydoan not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/mariajoynson not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/katiesfitz not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/amyastridd not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/kayedinsleyx not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/hope_x.m not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/nhutella_ not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/jonjovellanos not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/kevindillonofficial not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/kevinvanegas not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/fitmencook not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/kevinjdebruin not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/stevenadams not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/stevenkelly not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/stevenxzuber not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/stevengrossman not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/thestvn_ not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/stevenmcbee not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/dxb_hun not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/stevendengg not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/stevenplevine not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/stevenchevrin not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/seagalofficial not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/navito_halal not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/freespiritedlatina not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/draminayonis not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/teepillay not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/haydncorke not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/botanygeek not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/haikettua_atl not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/jun_yuh not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/iamsarahsnow not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/salma.masrour not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/smilewithjeryl not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/briansegnaro not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/bryancranston not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/markmanson not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/afantano not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/theanthonyedwards_ not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/mr.6ways not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/anthonygargiula not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/theanthonyvicino not found. Skipping this user.
# Warning: User directory /content/drive/MyDrive/PFA-Dataset/Images/kevinlevrone not found. Skipping this user.

# %%
import torch
import numpy as np
from sklearn.metrics import classification_report, hamming_loss, confusion_matrix

# Ensure the model is in evaluation mode
model.eval()

# Variables to store all labels and predictions
all_labels = []
all_preds = []

# Disable gradient calculation for inference
with torch.no_grad():
    for images, labels in dataloader:
        # Get model predictions
        outputs = model(images)
        preds = torch.sigmoid(outputs) > 0.5  # Convert logits to binary predictions

        # Store labels and predictions
        all_labels.append(labels.cpu().numpy())
        all_preds.append(preds.cpu().numpy())

# Concatenate all predictions and labels
all_labels = np.vstack(all_labels)
all_preds = np.vstack(all_preds)

# Print classification report
print("Classification Report")
print(classification_report(all_labels, all_preds, target_names=['O', 'C', 'E', 'A', 'N'], zero_division=0))

# Calculate and print Hamming Loss
ham_loss = hamming_loss(all_labels, all_preds)
print(f'Hamming Loss: {ham_loss}')

# Print confusion matrix for each label
print("Confusion Matrix for Each Label")
for i, label in enumerate(['O', 'C', 'E', 'A', 'N']):
    cm = confusion_matrix(all_labels[:, i], all_preds[:, i])
    print(f'Confusion Matrix for {label}:\n{cm}\n')
# Out:
# Classification Report
#               precision    recall  f1-score   support
#
#            O       0.70      1.00      0.82        35
#            C       0.58      1.00      0.73        29
#            E       0.00      0.00      0.00        21
#            A       0.67      0.73      0.70        33
#            N       0.00      0.00      0.00         6
#
#    micro avg       0.64      0.71      0.67       124
#    macro avg       0.39      0.55      0.45       124
# weighted avg       0.51      0.71      0.59       124
#  samples avg       0.65      0.68      0.64       124
#
# Hamming Loss: 0.34
# Confusion Matrix for Each Label
# Confusion Matrix for O:
# [[ 0 15]
#  [ 0 35]]
#
# Confusion Matrix for C:
# [[ 0 21]
#  [ 0 29]]
#
# Confusion Matrix for E:
# [[28  1]
#  [21  0]]
#
# Confusion Matrix for A:
# [[ 5 12]
#  [ 9 24]]
#
# Confusion Matrix for N:
# [[44  0]
#  [ 6  0]]

# %%
model = UserClassifier(num_labels=5)
model.load_state_dict(torch.load('/content/drive/Shareddrives/PFA_Dataset/models/cnnUser.pth'))
print(model)
# Out:
# UserClassifier(
#   (feature_extractor): ResNet(
#     (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#     (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (relu): ReLU(inplace=True)
#     (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#     (layer1): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer2): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer3): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (layer4): Sequential(
#       (0): BasicBlock(
#         (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (downsample): Sequential(
#           (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#           (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         )
#       )
#       (1): BasicBlock(
#         (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (relu): ReLU(inplace=True)
#         (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#         (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#     (fc): Identity()
#   )
#   (fc): Linear(in_features=512, out_features=5, bias=True)
# )
