# %%
import os
import requests
from datetime import datetime
import json
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Load users data from users.json
with open('/content/drive/MyDrive/test/users.json', 'r') as f:
    users_data = json.load(f)

# Define function to upload image to Drive
def upload_image_to_drive(image_url, image_name, folder_path):
    # Download the image from the URL
    response = requests.get(image_url)
    # Save the image to the specified folder
    with open(os.path.join(folder_path, image_name), 'wb') as img_file:
        img_file.write(response.content)
    print(f"'{folder_path} : 'Image '{image_name}' downloaded and saved in Google Drive.")

# Specify the parent folder name where you want to organize the images
parent_folder_name = 'PFA-Dataset'

# Specify the folder name under the parent folder where you want to store the images
images_folder_name = 'images'

# Get the parent folder ID (replace 'YOUR_PARENT_FOLDER_ID' with the actual parent folder ID)
parent_folder_id = '1j79Cy8JuvUZ4ab6N0USHVY45qM1IsRhz'  # Update with the correct parent folder ID

# Create the 'images' folder under the parent folder if it doesn't exist
images_folder = os.path.join('/content/drive/My Drive', parent_folder_name, images_folder_name)
os.makedirs(images_folder, exist_ok=True)

# Control how many users' images to upload at a time
users_to_upload = 200  # Change this value as needed

# Upload images for each user into the 'images' folder
users_processed = 0
for user_data in users_data:

    username = user_data.get('user')
    if not username:
        print("Warning: User has no username.")
        continue

    user_folder = os.path.join(images_folder, username)
    os.makedirs(user_folder, exist_ok=True)  # Create user folder if it doesn't exist

    for post in user_data['posts']:
        media_url = post.get('media_url')
        thumbnail_url= post.get('thumbnail_url')
        image_url = None
        if media_url :
            image_url = media_url
        elif thumbnail_url:
            image_url = thumbnail_url

        # Generate photo_id using timestamp_seconds
        timestamp = datetime.strptime(post['timestamp'], "%Y-%m-%dT%H:%M:%S+0000")
        timestamp_seconds = int(timestamp.timestamp())
        photo_id = f"{timestamp_seconds}"  # Custom photo_id format

        # Update the 'media_url' to 'photo_id' with its corresponding value
        post['photo_id'] = photo_id
        if media_url:
            del post['media_url']  # Remove the 'media_url' key
        if thumbnail_url:
            del post['thumbnail_url']  # Remove the 'thumbnail_url' key
        if image_url:
            timestamp = datetime.strptime(post['timestamp'], "%Y-%m-%dT%H:%M:%S+0000")
            timestamp_seconds = int(timestamp.timestamp())
            # Upload the image to the user's folder
            upload_image_to_drive(image_url, f"{timestamp_seconds}.jpg", user_folder)
        else:
            print("Warning: 'media_url' not found for a post.")

    # Write the modified users_data back to users.json after processing all posts for each user
    with open('/content/drive/MyDrive/test/users.json', 'w') as f:
        json.dump(users_data, f)

print("photo_id written to users.json and media_url removed for each photo downloaded.")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1714057008.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1713552075.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1712693127.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1712013006.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1711215555.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1698948069.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1698360854.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1696438899.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1695758578.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1694616027.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1693516247.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1693326416.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1692041817.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1691870420.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1691794679.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1691755496.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1691687055.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1691611394.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1691519198.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1691350278.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1691169804.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1691013379.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1690936913.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1690079614.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1688321362.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1688138137.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1686780279.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1685588363.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1684178748.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1683151341.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1682558447.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1682458294.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1682346332.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1682188491.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1682083888.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1682026781.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1681823113.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1681341813.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1681223103.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1680721882.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1680644234.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1680551975.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1680097678.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1680026483.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1679439214.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1679251470.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1679006645.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1678665101.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1678551745.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1678227849.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1678040065.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1677947747.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1677436535.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1677073550.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1676919134.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1675959620.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1674924676.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1673650835.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1673457853.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1672936085.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1672885121.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1672243614.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1668798923.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1668608567.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1668546218.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1668454238.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1667329150.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1666984972.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1666883481.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1666634039.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1665538469.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1663103032.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1662652236.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1661547114.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1660965236.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1660865399.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1660237747.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1660147534.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1660146565.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1660141803.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1659883352.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1659712479.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1659454171.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1659395139.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1659062932.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1658853617.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1658791688.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1658760318.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1658502305.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1658444223.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1657906294.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1656464903.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1656029129.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1654031886.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1652911870.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1652894326.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1652373802.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1652371294.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1652305543.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/emilyhenrywrites : 'Image '1651581641.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/humminglion : 'Image '1714528580.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/humminglion : 'Image '1714104471.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/humminglion : 'Image '1713837962.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/humminglion : 'Image '1713624236.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/humminglion : 'Image '1713539405.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/humminglion : 'Image '1713384793.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/humminglion : 'Image '1713283314.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/humminglion : 'Image '1713112885.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/humminglion : 'Image '1712934549.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/humminglion : 'Image '1712844572.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/humminglion : 'Image '1712678338.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/humminglion : 'Image '1712506070.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/humminglion : 'Image '1712414467.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/humminglion : 'Image '1712252396.jpg' downloaded and saved in Google Drive.
# '/content/drive/My Drive/PFA-Dataset/images/humminglion : 'Image '1712079388.jpg' downloaded and saved in Google Drive.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-13-da2f54110f6c> in <cell line: 41>()
#      73             timestamp_seconds = int(timestamp.timestamp())
#      74             # Upload the image to the user's folder
# ---> 75             upload_image_to_drive(image_url, f"{timestamp_seconds}.jpg", user_folder)
#      76         else:
#      77             print("Warning: 'media_url' not found for a post.")
#
# <ipython-input-13-da2f54110f6c> in upload_image_to_drive(image_url, image_name, folder_path)
#      15 def upload_image_to_drive(image_url, image_name, folder_path):
#      16     # Download the image from the URL
# ---> 17     response = requests.get(image_url)
#      18     # Save the image to the specified folder
#      19     with open(os.path.join(folder_path, image_name), 'wb') as img_file:
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in get(url, params, **kwargs)
#      71     """
#      72
# ---> 73     return request("get", url, params=params, **kwargs)
#      74
#      75
#
# /usr/local/lib/python3.10/dist-packages/requests/api.py in request(method, url, **kwargs)
#      57     # cases, and look like a memory leak in others.
#      58     with sessions.Session() as session:
# ---> 59         return session.request(method=method, url=url, **kwargs)
#      60
#      61
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     587         }
#     588         send_kwargs.update(settings)
# --> 589         resp = self.send(prep, **send_kwargs)
#     590
#     591         return resp
#
# /usr/local/lib/python3.10/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     701
#     702         # Send the request
# --> 703         r = adapter.send(request, **kwargs)
#     704
#     705         # Total elapsed time of the request (approximately)
#
# /usr/local/lib/python3.10/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     484
#     485         try:
# --> 486             resp = conn.urlopen(
#     487                 method=request.method,
#     488                 url=url,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     789
#     790             # Make the request on the HTTPConnection object
# --> 791             response = self._make_request(
#     792                 conn,
#     793                 method,
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535         # Receive the response from the server
#     536         try:
# --> 537             response = conn.getresponse()
#     538         except (BaseSSLError, OSError) as e:
#     539             self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# /usr/local/lib/python3.10/dist-packages/urllib3/connection.py in getresponse(self)
#     459
#     460         # Get the response from http.client.HTTPConnection
# --> 461         httplib_response = super().getresponse()
#     462
#     463         try:
#
# /usr/lib/python3.10/http/client.py in getresponse(self)
#    1373         try:
#    1374             try:
# -> 1375                 response.begin()
#    1376             except ConnectionError:
#    1377                 self.close()
#
# /usr/lib/python3.10/http/client.py in begin(self)
#     316         # read until we get a non-100 response
#     317         while True:
# --> 318             version, status, reason = self._read_status()
#     319             if status != CONTINUE:
#     320                 break
#
# /usr/lib/python3.10/http/client.py in _read_status(self)
#     277
#     278     def _read_status(self):
# --> 279         line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280         if len(line) > _MAXLINE:
#     281             raise LineTooLong("status line")
#
# /usr/lib/python3.10/socket.py in readinto(self, b)
#     703         while True:
#     704             try:
# --> 705                 return self._sock.recv_into(b)
#     706             except timeout:
#     707                 self._timeout_occurred = True
#
# /usr/lib/python3.10/ssl.py in recv_into(self, buffer, nbytes, flags)
#    1301                   "non-zero flags not allowed in calls to recv_into() on %s" %
#    1302                   self.__class__)
# -> 1303             return self.read(nbytes, buffer)
#    1304         else:
#    1305             return super().recv_into(buffer, nbytes, flags)
#
# /usr/lib/python3.10/ssl.py in read(self, len, buffer)
#    1157         try:
#    1158             if buffer is not None:
# -> 1159                 return self._sslobj.read(len, buffer)
#    1160             else:
#    1161                 return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import os
from google.colab import drive

# Mount Google Drive
drive.mount('/content/drive')

# Path to the directory containing user folders
pfa2_directory = '/content/drive/My Drive/pfa2/images'

# Dictionary to store the count of images per username
folder_image_counts = {}

# Function to count images recursively
def count_images(folder_path):
    total_images = 0
    # Iterate over the contents of the folder
    for item in os.listdir(folder_path):
        item_path = os.path.join(folder_path, item)
        # Check if the item is a directory
        if os.path.isdir(item_path):
            # Recursively count images in subfolders
            total_images += count_images(item_path)
        # Check if the item is a file (image)
        elif os.path.isfile(item_path):
            total_images += 1
    return total_images

# Count of folders under pfa2/images
folder_count = 0

# Iterate over the folders in the pfa2 directory
for username_folder in os.listdir(pfa2_directory):
    # Increment folder count
    folder_count += 1

    # Construct the full path to the username folder
    username_folder_path = os.path.join(pfa2_directory, username_folder)

    # Check if the item in the directory is a folder
    if os.path.isdir(username_folder_path):
        # Count the number of images in the folder and its subfolders
        num_images = count_images(username_folder_path)

        # Store the count in the folder_image_counts dictionary
        folder_image_counts[username_folder] = num_images

# Print the number of folders under pfa2/images
print(f"Number of folders under 'pfa2/images': {folder_count}")

# Print the image counts per username folder less than 100
print("Folders with image count less than 100:")
for username, count in folder_image_counts.items():
    if count < 100:
        print(f"{username}: {count} images")
